# %%
import tweepy
from textblob import TextBlob
from wordcloud import WordCloud
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re

# %%
API_Key = "KdtRkUIfVXzOOyTL5bWIJ28gf"
API_Key_Secret = "USJ00an7KpDdJYVDcNhCLHPnVohnVgkeebaGe3Gp8CWHi9ZZnC"
Access_Token = "1442726092133920772-HjJpIWNzHC6PUS9zirhRJPxKhKcRuj"
Access_Token_Secret = "uDvHqkTAeWWBhkyuF8zoJsawdC5JupSSimaWOvMUTjHRm"

# %%
print(API_Key)
print(API_Key_Secret)
print(Access_Token)
print(Access_Token_Secret)
# Out:
# KdtRkUIfVXzOOyTL5bWIJ28gf
# USJ00an7KpDdJYVDcNhCLHPnVohnVgkeebaGe3Gp8CWHi9ZZnC
# 1442726092133920772-HjJpIWNzHC6PUS9zirhRJPxKhKcRuj
# uDvHqkTAeWWBhkyuF8zoJsawdC5JupSSimaWOvMUTjHRm

# %%
authenticate = tweepy.OAuthHandler(API_Key,API_Key_Secret)
authenticate.set_access_token(Access_Token,Access_Token_Secret)
api = tweepy.API(authenticate,wait_on_rate_limit=True)

# %%
posts = api.user_timeline(screen_name = "RNTata2000", count=150, tweet_mode="extended")

# %%
i = 1
for p in posts[0:5]:
    print(i,')',p.full_text,"\n")
    i=i+1
# Out:
# 1 ) Welcome back, Air India 🛬🏠 https://t.co/euIREDIzkV
#
# 2 ) Congratulations to Airbus Defence, Tata Advanced Systems Limited and the Indian Defence Ministry 🤝 @tataadvanced @indiandefence @AirbusDefence @TataCompanies https://t.co/3pNvA4slMR
#
# 3 ) https://t.co/lPeskCkt1r
#
# 4 ) https://t.co/CjAR6LzIah
#
# 5 ) Very thankful to have gotten my first vaccination shot today. It was effortless and painless. I truly hope everyone can be immunised and protected soon.

# %%
df  = pd.DataFrame([t.full_text for t in posts],columns=['Tweets'])

# %%
df.head()
# Out:
#                                               Tweets
# 0  Welcome back, Air India 🛬🏠 https://t.co/euIRED...
# 1  Congratulations to Airbus Defence, Tata Advanc...
# 2                            https://t.co/lPeskCkt1r
# 3                            https://t.co/CjAR6LzIah
# 4  Very thankful to have gotten my first vaccinat...

# %%
def clean_txt(text):
    text = re.sub(r"@[A-Za-z0-9]+","",text) # removes @mentions
    text = re.sub(r"#","",text) # removes #
    text = re.sub(r"RT[\s]+","",text) # removes RT re tweet followed by \s-blank spaces
    text = re.sub(r"https?:\/\/\S+","",text) # removes hyperlink
    
    return text

df['Tweets'] = df['Tweets'].apply(clean_txt)

# %%
df['Tweets'][2]
# Out:
# ''

# %%
def getSubjectivity(text):
    return TextBlob(text).sentiment.subjectivity

def getPolarity(text):
    return TextBlob(text).sentiment.polarity

df['Subjectivity'] = df['Tweets'].apply(getSubjectivity)
df['Polarity'] = df['Tweets'].apply(getPolarity)

# %%
df.head()
# Out:
#                                               Tweets  Subjectivity  Polarity
# 0                        Welcome back, Air India 🛬🏠       0.450000  0.400000
# 1  Congratulations to Airbus Defence, Tata Advanc...      0.371429  0.164286
# 2                                                         0.000000  0.000000
# 3                                                         0.000000  0.000000
# 4  Very thankful to have gotten my first vaccinat...      0.316667  0.225000

# %%
all_words = " ".join([twts for twts in df['Tweets']])
word_cloud = WordCloud(background_color='white',
                          width=1920,
                          height=1080).generate(all_words)

plt.subplots(figsize=(25,10))
plt.imshow(word_cloud,interpolation="bilinear")
plt.axis('off')
plt.show()
plt.savefig('WorldCloud.png')

# %%
def getAnalysis(score):
    if score < 0:
        return "Negative"
    elif score == 0:
        return "Neutral"
    else:
        return "Positive"
    
df['Analysis'] = df['Polarity'].apply(getAnalysis)

# %%
df.head()
# Out:
#                                               Tweets  Subjectivity  Polarity  \
# 0                        Welcome back, Air India 🛬🏠       0.450000  0.400000
# 1  Congratulations to Airbus Defence, Tata Advanc...      0.371429  0.164286
# 2                                                         0.000000  0.000000
# 3                                                         0.000000  0.000000
# 4  Very thankful to have gotten my first vaccinat...      0.316667  0.225000
#
#    Analysis
# 0  Positive
# 1  Positive
# 2   Neutral
# 3   Neutral
# 4  Positive

# %%
j=1
sortedDF = df.sort_values(by=['Polarity'])
for i in range(0, sortedDF.shape[0]):
    if(sortedDF['Analysis'][i]=='Positive'):
        print(str(j) + ')'+sortedDF['Tweets'][i])
        print()
        j=j+1
# Out:
# 1)Welcome back, Air India 🛬🏠
#
# 2)Congratulations to Airbus Defence, Tata Advanced Systems Limited and the Indian Defence Ministry 🤝
#
# 3)Very thankful to have gotten my first vaccination shot today. It was effortless and painless. I truly hope everyone can be immunised and protected soon.
#
# 4)My best wishes to all the Tata group companies, the employees &amp; their families on the birth anniversary of our founder, Mr. Jamsetji Tata, who has inspired us with his kindness over the years.
#
# This founder’s day has special emotions for me, reminding me of my mentor Mr. JRD Tata
#
# 5)While I appreciate the sentiments expressed by a section of the social media in terms of an award, I would humbly like to request that such campaigns be discontinued.
#
# Instead, I consider myself fortunate to be an Indian and to try and contribute to India’s growth and prosperity
#
# 6)Congratulations on the 4 million milestone! I wish you all the very best for the road ahead.
#
#  _Cars
#
#
#
# 7): Celebrating the spirit of self-reliance, we are proud of our weavers who, with the help of Antaran honed their entrepreneur…
#
# 8)As happy as I am to support this venture, it has been a minority token investment.
# I have not purchased 50% stake in the company.
#
# 9)This post has neither been said, nor written by me. I urge you to verify media circulated on WhatsApp and social platforms. If I have something to say, I will say it on my official channels. Hope you are safe and do take care.
#
# 10)The COVID 19 crisis is one of the toughest challenges we will face as a race. The Tata Trusts and the Tata group companies have in the past risen to the needs of the nation. At this moment, the need of the hour is greater than any other time.
#
# 11)The idea is not to test the limits of our planet and find out how much more damage it can take, but to come together and begin restoration and reversal. We owe it to every generation that comes after.
#
# 12)It makes me so happy that the Government of Odisha was awarded with the World Habitat Award for the Jaga mission with the Tata Trusts and the Norman Foster Foundation for giving slum dwellers land rights and livable habitat. We are only as strong as the communities we empower.
#
# 13)I don’t know about breaking the internet, but I am so excited to join all of you on Instagram (ratantata)! After a long absence from public life, I look forward to exchanging stories and creating something special with such a diverse community!
#
# 14)Voting is the most powerful right of every citizen and it is our duty to exercise our vote. Please vote, our future depends on it!
#
# 15)We congratulate the PM and the IAF for the successful air strikes on the terrorist training camps which Pakistan has claimed never existed! India is proud of the firm action taken in retaliation to the suicide attack on our soldiers a few days ago.
#
# 16)I’m excited to announce that I’m again judging ' The Peninsula Classics Best of the Best Award, winner of which will be revealed live from  on 7 Feb 2019. Scroll through to see 8 nominees. penmoments bestofthebest2018
#
# 17): Had a wonderful interaction with a group of mountaineering enthusiasts who are embarking on an expedition to spread aware…
#
# 18)Proud to have been awarded an honorary degree &amp; fellowship from  in recognition of our partnership work on steel energy in Wales and UK   _specific _Swansea _Cymru
#
# 19): 4/4 I am also delighted to share that ACCF has started working on recruitment of clinical staff for screening programme a…
#
# 20): 2/4 17 of 18 locations for cancer hospitals have been finalised &amp; construction will start in 2 months. Happy to share tha…
#
# 21)All of us who knew Mr. Atal Bihari Vajpayee are saddened to hear of his passing away. He was a great leader with a great sense of compassion and humor. He will be remembered fondly by a vast number of us.
#
# 22)   Pleasure mtng Shri  with CM _Fadnavis &amp; other dignitaries. Impressed to learn of progress in implementing Hon’ble PM ’s various national initiatives &amp; reforms  over past 4 yrs. Also discussed commitment of  to support major national programs.
#
# 23)Visited Google. Pleasure to meet Larry, Sergey and Sundar again. Excited by new technologies which will have huge impact in years ahead.
#
# 24)Delighted to inaugurate Naval Tata Hockey Academy in Jamshedpur. Will help young take to India’s national sport with greater vigour.
#
# 25)I wish to express my appreciation to all those involved in the NCLT, and particularly the high integrity of the judicial process.
#
# 26)Delighted to be back in Jamshedpur. Where it all began...
#
# 27)Happy to share my letter to my colleagues on this 178th birth anniversary of our Founder Jamsetji Tata
#
# 28)Local body elections are scheduled on February 16th and 21st in Maharashtra. Let’s pledge to vote for a strong future. VoteKarMaharashtra
#
# 29)The government’s bold implementation of the demonetization programme needs the nation’s support.
#
# 30)Demonetisation of old currency notes by the Modi govt is a bold act that will wipe out black money and corruption. It deserves our support
#
# 31)Hearty congratulations to India's armed forces and Intel agencies for successful surgical retaliatory action against Pak terrorist camps.
#
# 32)So proud of Indian govt's firm stand on bycot of SARC mtg &amp; overwhelming support by member nations.
#
# 33)Grateful for wide support for AVANTI FINANCE. Committed to make affordable and safe finance available to the underserved population.
#
# 34)Deeply touched by the kind sentiments &amp; best wishes from well wishers. Thanks so much .
#
# 35)Felt proud to be with enthusiastic, young entrepreneurs at T-Hub, the new incubator at Hyderabad. I wish them all the best.
#
# 36)Good article, well worth reading.
#
#
# 37)I congratulate David Cameron on his great victory. I am overjoyed that he will continue to lead the UK to greater heights in the years ahead
#
# 38)Wonderful to see US &amp; India come together in a bond of mutual friendship and trust. Both charismatic leaders deserve great credit and praise
#
# 39)  Best wishes for the New Year. Hope it's a great                       year with all your hopes and wishes realised.
#
# 40)I want to thank those who sent me birthday greetings for their kind words and thoughtfulness.
#
# 41)My deepest condolences go out to the families of the innocent students in Pakistan who were shot yesterday  in an unforgivable massacre.
#
# 42)I salute the govt for encouraging new airlines to fly in India, so that travellers can reach their destinations faster at affordable prices.
#
# 43)bringbackourgirls it is time to rescue the ChibokGirls and bring them home – supporting  Commissioner  &amp; all her efforts
#
# 44)The nation voted 4 change. We need 2 stand together 2 support the new Govt's actions  to re-build economic growth and prosperity in India.
#
# 45)Mr. Modi's landslide victory echoes the people's mandate for strong leadership and clear policies for growth and prosperity for India.
#
# 46)Dr.Manmohan Singh demits office this week after 10 yrs. He led with great dignity and displayed high personal values.
#
# 47)Greatly honored to receive recognition from UK so graciously bestowed by Her Majesty. See link for press statement.
#
# 48)Wishing you all a very happy new year. I hope 2014 brings you everything you wish for, and that yr dreams are fulfilled
#
# 49)I greatly appreciate the kind sentiments and greetings received on my birthday. They mean a lot to me. I wish you all a happy new year.
#
# 50)The world has lost a great leader. Nelson Mandela was the father of a free South Africa where all people had equal rights. He will be missed
#
# 51)Great to see the genuine public adoration for Sacin Tendulkar. He has truly made us all proud. He has achieved so much with such humility.
#
# 52)Was Inducted today into the National Academy of Engineering. This has been a great moment for me!
#
#
#
# 53)  this would be of interest to me. Pl indicate a best way contact with a view to know more of what you are doing.
#
# 54):  NANO IN MYANMAR. GLAD AND PROUD TO SEE. MERA BHARAT MAHAAN
#
# 55) thank you so much for the image of the Nano in Myanmar. It has made my day!
#
# 56)Feel proud to see so many young Indians making their contribution . Lovely place to work!
#
# 57)Visited Google HQ today - A terrific company, great innovation &amp; inspiring leadership. Hope India can create a "Google environment" one day!
#
# 58) Will certainly try to do so one day.
#
# 59)The Tata Medical Centre in Kolkata now fully occupied, filled mainly with children suffering from Leukemia. Hope we can save many lives.
#
# 60)Thank you all for your caring and thoughtful messages .
#
# 61)My good friend Dr Amar Bose passed away today. He was respected for his sharp mind and for his humility. The world has lost a great leader.
#
# 62)Delighted with fantastic response to AirAsia hiring of flight attendants. Great opportunity for young Indians. Makes me feel very proud.
#
# 63)At the Geneva Motor show - my first after retirement. It is wonderful to meet many close friends again and view all the new cars.
#
# 64)My deepest appreciation and thanks for the thoughtful messages for my birthday. I am so deeply touched by the kind sentiments expressed.
#
# 65)Most people don't recognise the tremendous potential in Saudi Arabia. It is truly a vibrant business environment with impressive people.
#
# 66)A great day! Tatas / JLR signed an agreement to produce Land Rovers in Saudi Arabia. It is the first intl car co. to do this.
#
# 67) I agree. Such attacks are well planned. Defense measures need to be elaborate to provide real deterrent against future attacks.
#
# 68) Difficult to name "best car". Have driven many which impressed me. TML working hard to produce higher-end cars.
#
# 69)A Gr8 day for friends Ralf Speth, Ian Cullam, Gerry McGovern and the team at JLR. Proud of their spirit &amp; excitement. My thanks to all.
#
# 70)Memorable day today. Launch of Jaguar's new F-type sports car and new Range Rover. Gr8 +ve response. Gr8 sense of pride for all at JLR!
#
# 71)Spent a very worthwhile day on Sunday at Pebble Beach, California, feasting my eyes on an unbelievable collection of .. (1/2)
#
# 72)..beautiful classic cars. Amazed at the level of technology applied decades ago.  (2/2)
#
# 73)Dhanush’s rhythmic song &amp; video is creative and unique. I would like to thank Dhanush and express my appreciation.
#
# 74)I am exhilarated by the success of Jaguar LandRover. There were many critics when we acquired the company. I hope they feel happy now.
#
# 75) I fly a Falcon Business Jet but the most exciting aircraft I have flown is an F-18 fighter last February.
#
# 76)Thank you all for the thoughtful responses. The consistency is overwhelming. We must try to do something meaningful.
#
# 77)What should we do to make India a land of equal opportunity for all, free of prejudice and discrimination?
#
# 78) Tata Motors is an Indian company with operations and assets overseas. Hope we could keep the Indian flag flying high.
#
# 79) Really appreciate your support. PS and diesel variants of the Nano are in our future plans.
#
# 80)It was good to be at the Geneva Motor Show where we displayed our new Mega Pixel concept car. I am delighted to be home again.
#
# 81)My apologies for the long silence. There were requests for picture of my German Shepherds,which I am pleased to attach.
#
# 82) Yes - absolutely true Siddarth. Dogs total loyalty is unequal and should be wholly reciprocated.
#
# 83) Tito is a 5 yr old German Shepherd.
#
# 84) thanks so much
#
# 85)My dogs Tito and Tango make it so enjoyable to come home each evening. They wait for me and give me their undivided affection.
#
# 86)..vigor and their energy could have a profound impact on the shape of the India of tomorrow. One hopes the country will be .. (2/7)
#
# 87)..opportunity for all. The youth of today will need to recognize that they shoulder a great responsibility. They will need to .. (4/7)
#
# 88)..first" instead of communal or geographic factions. They will need to strive for excellence while personally upholding high .. (6/7)
#
# 89)..ethical standards and values. I wish our young people all the very best for the New Year.  (7/7)
#
# 90)Had a wonderful and refreshing meeting with Dhanush. He has unleashed the power of communicating unconventionally with the masses.
#
# 91)The swift and firm action of the Chief Minister is commendable. The heroic actions by the 3 deceased staff members also needs recognition.

# %%
j=1
sortedDF = df.sort_values(by=['Polarity'])
for i in range(0, sortedDF.shape[0]):
    if(sortedDF['Analysis'][i]=='Negative'):
        print(str(j) + ')'+sortedDF['Tweets'][i])
        print()
        j=j+1
# Out:
# 1)In past difficult times, entrepreneurs have displayed far sightedness and creativity that could not have been believed to exist. These became the flagpoles of innovation and new technology today. Read at
#
# 2)I’m afraid this too, has not been said by me. I will endeavour to call out fake news whenever I can, but would encourage you to always verify news sources. My picture alongside a quote does not guarantee me having said it, a problem that many people face.
#
# 3)A lot has been said about the tragedy of 26/11. The memory of the carnage and loss of life, is still painful. We won't forget the needless suffering caused across the city. But we remain proud of the spirit and the sense of unity of Mumbai. We can be hurt, but not knocked out.
#
# 4)Always feel nostalgic and inspired when in Jamshedpur... Founder’s Day is always special.
#
# 5)Shocked my a/c was hacked yesterday &amp; spurious tweet sent with malicious intent.Tweet deleted, a/c restored. C link.
#
# 6)My heart goes out to those on board the missing AirAsia flight , their friends and relatives at this difficult time.
#
# 7)Sorry to know of the sad passing away of Mr. Yash Chopra, who has left his mark on Indian films- a gr8 professional and a very warm person.
#
# 8)Sorry for the silence. Am presently in Braziland will be back towards month-end.
#
# 9)_cool_tata Dear Mr. Sharma, sorry to hear that your father is hospitalised. I wish him a speedy recovery.
#
# 10)Tito and Tango seek nothing in return for their affection other than love and attention. I miss them terribly when I am away.
#
# 11)The New Year will be dawning in a few days. The next decade can be the decade of the youth of India - their voice, their .. (1/7)
#
# 12)..driven by meritocracy, while being sensitive to the needs of the less privileged, and truly become a nation of equal .. (3/7)

# %%
j=1
sortedDF = df.sort_values(by=['Polarity'])
for i in range(0, sortedDF.shape[0]):
    if(sortedDF['Analysis'][i]=='Neutral'):
        print(str(j) + ')'+sortedDF['Tweets'][i])
        print()
        j=j+1
# Out:
# 1)
#
# 2)
#
# 3)
#
# 4)
#
# 5)In the spirit of solidarity
#
# 6)The crowd of people on launch day showed that it wasn’t just about the coffee, but also about relationships. Wishing  a Venti-hearted 7 year anniversary month since the inception of Tata-Starbucks with the vision of of Mr. R. K Krishnakumar and Mr. Howard Schultz.
#
# 7) and swachhbharat
#
# The Tata Trusts fully support Swachhata Hi Seva. We will do a cleanliness drive on 15th September.
#
# 8): 3/4 ACCF has also started cancer screening programme in the districts along with palliative care strengthening. I am sure…
#
# 9): 1/4 Yesterday, I chaired Board of Directors' meeting of Assam Cancer Care Foundation (ACCF). ACCF has started implementat…
#
# 10)_India: Under the Rashtriya POSHANAbhiyaan we have decided to increase the annual rate of reduction of anaemia from 1 to 3%. In thi…
#
# 11)The attached tweet could help fulfill a design to feed 1 billion people. Please see attached.
#
# 12)Celebrating birthdate of founder Jamsetji Tata. His vision of industrial development &amp; giving back wealth to society has stood test of time.
#
# 13)Updated link: Global elimination of malnutrition is an attainable goal-invest in nutrition. Join
#
# 14)Global elimination of malnutrition is an attainable goal - invest in nutrition. Join
#
# 15)
#
# 16)
#
# 17)Congratulations to Chandra! See link.
#
# 18)Some further thoughts on implementation of demonetization program.
#
# 19)5/20 Rule and Vested Interests
#
# 20) RNTata2000
#
# 21)
#
# 22)   Thank you afzalkhan
#
# 23)Help us reach 250,000 voices for highseas ocean health and protection. Sign and retweet  petition!
#
# 24)If you care for the ocean as I do, please click here and sign the  petition
#
# 25)The ocean is essential for all life on earth - ­ time to protect it.
# Please join me and sign the petition
#
# 26)Tks 4 suprt.Nev spoke of ind dev in State-only view fm car in Rajarhat fm airprt 2 Sonar.Mitra's angr needless.C link
#
# 27): England have retained the Ashes....
#
# 28)We overlook importance of oceans on our planet. We must preserve this essential resource. Go to  and make yr comments.
#
# 29) , pl  write me at Elphinston Bldg, 3fl., Horniman Circle, Mumbai. Will try to help yr son.
# RNT
#
# 30)I compliment Dr. Chandy and all his colleagues for their dedication to treat the patients at the Tata Medical Centre.
#
# 31)FIPB approval of the airline project between Tatas, Air Asia and Bhatias (cont)
#
# 32)Life after retirement
#
# 33)Saying Farewell
#
# 34)Today is the anniversary of the terrorist attack on Mumbai 4 yrs ago. My sympathies go out all those who were affected by the attack.
#
# 35)
#
# 36)Corruption should be fought but I hope it will not be driven by rivalry. The law should apply to all equally, not selectively.
#
# 37)Apologies for the Silence. Depressed to see the attacks on India. Felt obliged to express my feelings. (Attached)
#
# 38)Should the Media pursue sensationalism & misinformation rather than upholding their responsibility of reporting news factually?
#
# 39): Education is the key to making India a land of equal opportunity: Responses to Ratan Tata's Survey summarized. http ...
#
# 40) . You can contact me on rntata.com
#
# 41) E Mail is rntata.com
#
# 42)
#
# 43) Yes I wish they were!!
#
# 44)..fight for rooting out corruption, for ensuring that no one is above the law, and uniting the citizens of India as "Indians .. (5/7)
#
# 45) how can I help?
#
# 46) - The star of Kolaveri di!
#
# 47)My sympathies go out to the families of patients and the three staff members that have lost their lives in an attempt to rescuing patients.

# %%
plt.figure(figsize=(8,6))
for i in range(0,df.shape[0]):
    plt.scatter(df['Polarity'][i],df['Subjectivity'][i],color="Blue")
    
plt.title('Sentiment Analysis')
plt.xlabel('Polarity')
plt.ylabel('Subjectivity')
plt.show()
fig = plt.figure()
fig.savefig('ScatterPlot.jpg',dpi=100)

# %%
print("Positive Tweets: ",round((df[df.Analysis=='Positive'].shape[0]/df.shape[0])*100))
print("Neutral Tweets : ",round((df[df.Analysis=='Neutral'].shape[0]/df.shape[0])*100))
print("Negative Tweets: ",round((df[df.Analysis=='Negative'].shape[0]/df.shape[0])*100))
# Out:
# Positive Tweets:  61
# Neutral Tweets :  31
# Negative Tweets:  8

# %%
df['Analysis'].value_counts().plot(kind='bar')
plt.title('Sentiment Analysis')
plt.xlabel('Sentiment')
plt.ylabel('Counts')
plt.show()
fig = plt.figure()
fig.savefig('BarPlot.jpg',dpi=100)
